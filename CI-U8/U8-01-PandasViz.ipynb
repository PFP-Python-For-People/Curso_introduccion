# %% [markdown]
# # Unidad 8 - Introducción a la algoritmia con Python
# #### Elementos básicos de Python
#
# # Demo Pandas III - Visualización
#
# En este notebook vas a encontrar ejemplos relacionados con el uso de la librería Pandas en Python. Recuerda que siempre puedes ir a la referencia si tienes alguna duda [Ir a la referencia](https://numpy.org/doc/1.25/)
#
# Este archivo es la continuación de Pandas, iremos avanzando en algunos conceptos adicionales
#
# ##### Contenido de este archivo:
#
# 1. Importar la librería y ver la versión
#     - [[enlace]](#A01)
# 2. Tipos de gráficos
#     - [[enlace]](#A02).
# 3. Cambio de color y estilos
#     - [[enlace]](#A03).

# %% [markdown]
# ### 1. Importar la librería y ver la versión
# [[enlace]](#A00)

# %%
import pandas as pd
pd.__version__
# Out:
# '1.1.3'

# %% [markdown]
# ### 2. Tipos de gráficos
# [[enlace]](#A00)

# %% [markdown]
# #### Gráfico histograma

# %%
# Crear un DataFrame de ejemplo
data = {'Puntuaciones': [85, 90, 70, 65, 80, 95, 75, 60, 85, 90, 70, 65]}
df = pd.DataFrame(data)

# Crear el gráfico de histograma
df.plot.hist()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Gráfico de puntos

# %%
# Crear un DataFrame de ejemplo
data = {'w': [10, 15, 12, 8, 20, 14, 16],
        'h': [5, 8, 6, 4, 10, 7, 9]}
df = pd.DataFrame(data)

# Crear el gráfico de dispersión
df.plot.scatter(x='w', y='h')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Gráfico de línea

# %%
data = {'x': [1, 2, 3, 4, 5], 'y': [2, 4, 6, 8, 10]}
df = pd.DataFrame(data)
df.plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Gráfico barras

# %%
data = {'x': ['A', 'B', 'C', 'D', 'E'], 'y': [3, 6, 2, 7, 4]}
df = pd.DataFrame(data)
df.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Gráfico barras apiladas

# %%
data = {'x': ['A', 'B', 'C'], 'y1': [3, 6, 2], 'y2': [4, 2, 7]}
df = pd.DataFrame(data)
df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Gráfico barras horizontales

# %%
data = {'x': ['A', 'B', 'C', 'D'], 'y': [5, 3, 2, 6]}
df = pd.DataFrame(data)
df.plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Gráfico áreas

# %%
data = {'x': [1, 2, 7, 4, 5], 'y': [2, 4, 3, 8, 10]}
df = pd.DataFrame(data)
df.plot.area()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Gráfico de cajas y bigotes

# %%
data = {'x': ['A', 'A', 'B', 'B', 'C'], 'y': [3, 4, 6, 8, 5]}
df = pd.DataFrame(data)
df.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Gráfico torta

# %%
data = {'x': ['A', 'B', 'C'], 'y': [40, 25, 35]}
df = pd.DataFrame(data)
df.plot.pie(y='y')
# Out:
# <AxesSubplot:ylabel='y'>

# %% [markdown]
# #### Combinación con otras librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)
x = np.random.randn(100)
y = np.random.randn(100)
z = np.random.randn(100)

data = {'x': x, 'y': y, 'z': z}
df = pd.DataFrame(data)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['x'], df['y'], df['z'])
plt.show()

# %% [markdown]
# ### 3. Cambio de color y estilos
# [[enlace]](#A00)

# %%
data = {'x': [1, 2, 3, 4, 5], 'y': [2, 4, 6, 8, 10]}
df = pd.DataFrame(data)
df.plot(colormap='viridis')
# más colores en https://matplotlib.org/stable/tutorials/colors/colormaps.html
# Out:
# <AxesSubplot:>

# %%
data = {'x': [1, 2, 3, 4, 5], 'y1': [2, 4, 6, 8, 10], 'y2': [1, 3, 5, 7, 9]}
df = pd.DataFrame(data)
df.plot(color=['red', 'blue', 'green'])
# Out:
# <AxesSubplot:>

# %%
data = {'x': [1, 2, 3, 4, 5], 'y': [2, 4, 6, 8, 10]}
df = pd.DataFrame(data)
df.plot(style=['r--', 'bo'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Opciones para el estilado
#
# | Estilo | Descripción         |
# |--------|---------------------|
# | `'-'`  | Línea sólida        |
# | `'--'` | Línea punteada      |
# | `'-.'` | Línea guion-punto   |
# | `':'`  | Línea de puntos     |
# | `'.'`  | Puntos              |
# | `','`  | Puntos pequeños     |
# | `'o'`  | Círculos            |
# | `'v'`  | Triángulos hacia abajo |
# | `'^'`  | Triángulos hacia arriba |
# | `'<'`  | Triángulos hacia la izquierda |
# | `'>'`  | Triángulos hacia la derecha |
# | `'s'`  | Cuadrados           |
# | `'p'`  | Pentágonos          |
# | `'*'`  | Estrellas           |
# | `'+'`  | Cruces              |
# | `'x'`  | Aspas               |
# | `'D'`  | Diamantes           |
# | `'d'`  | Diamantes pequeños  |
# | `'h'`  | Hexágonos           |
# | `'H'`  | Hexágonos grandes   |

# %%
df.plot(style=['r-', 'bo'])
# Out:
# <AxesSubplot:>

# %%
df.plot(style=['g--', 'rs'])
# Out:
# <AxesSubplot:>

# %%
df.plot(style=['b-.', 'y*'])
# Out:
# <AxesSubplot:>

# %%
df.plot(style=['k:', 'gv'])
# Out:
# <AxesSubplot:>
