# %% [markdown]
# # Unidad 2 - Introducción a la algoritmia con Python
# #### Elementos básicos de Python
#
# # Demo Asignación y cambio en las variables
#
# En este notebook vas a encontrar ejemplos relacionados con los tipos de datos en Python, la declaración de variables y algunas instrucciones útiles, recuerda que siempre puedes ir a la referencia si tienes alguna duda [Ir a la referencia](https://docs.python.org/3.9/library/index.html)
#
# ##### Contenido de este archivo:
#
# 1. Operador de asignación
# 2. Cambio aritmético
# 3. Otros

# %% [markdown]
# ### 1. Operador de asignación

# %%
# En general la asignación de almacenamiento en memoria está basada
# en los lenguajes de programación en algun operador, en la mayoría
# este operador es el igual.

identificadorVariable = "Valor de la variable"

# %% [markdown]
# ![Recursos%20Gr%C3%A1ficos%20-%20Asignaci%C3%B3n.jpg](attachment:Recursos%20Gr%C3%A1ficos%20-%20Asignaci%C3%B3n.jpg)

# %% [markdown]
# ### 2. Cambio aritmético
#
# En ocasiones necesitamos realizar cambios sobre los valores numéricos, poara esto Python y otros lenguajes de programación cuentan con algunas opciones:

# %%
# Incremento manual
valor = 0
print("Inicial: " + str(valor))
valor = valor + 1
print("Final: " + str(valor))
# Out:
# Inicial: 0
# Final: 1

# %%
# Incremento resumido
valor = 0
print("Inicial: " + str(valor))
valor += 1
print("Final: " + str(valor))
# Out:
# Inicial: 0
# Final: 1

# %%
# Decremento manual
valor = 1
print("Inicial: " + str(valor))
valor = valor - 1
print("Final: " + str(valor))
# Out:
# Inicial: 1
# Final: 0

# %%
# Decremento resumido
valor = 1
print("Inicial: " + str(valor))
valor -= 1
print("Final: " + str(valor))
# Out:
# Inicial: 1
# Final: 0

# %%
# Multiplicación manual y resumida
valor = 2
print("Inicial: " + str(valor))
valor = valor * 2
print("Final: " + str(valor))

valor = 2
print("Inicial: " + str(valor))
valor *= 2
print("Final: " + str(valor))
# Out:
# Inicial: 2
# Final: 4
# Inicial: 2
# Final: 4

# %%
# División manual y resumida
valor = 8
print("Inicial: " + str(valor))
valor = valor / 2
print("Final: " + str(valor))

valor = 8
print("Inicial: " + str(valor))
valor /= 2
print("Final: " + str(valor))
# Out:
# Inicial: 8
# Final: 4.0
# Inicial: 8
# Final: 4.0

# %% [markdown]
# ### 3. Otros

# %% [markdown]
# #### Concatenación
#
# En el manejo de cadenas podemos realizar concatenación

# %%
# Sólo tipo cadena str
cadenaA = "una frase"
cadenaB = "otra frase"

# Se queda todo pegado
cadenaConcatenada = cadenaA + cadenaB
print(cadenaConcatenada)

# Arreglamos el formato
cadenaConcatenada = cadenaA +" "+ cadenaB
print(cadenaConcatenada)

# Forma especial con "la cadena f"
cadenaConcatenada = f'{cadenaA} {cadenaB}'
print(cadenaConcatenada)
# Out:
# una fraseotra frase
# una frase otra frase
# una frase ** otra frase

# %%
# Múltiples tipos de dato
variableA = "una frase"
variableB = 10
variableC = 1.75
variableD = ["A","B","C"]
 
## ---> cadenaConcatenada = variableA + variableB + variableC + variableD # Error
cadenaConcatenada = str(variableA) + str(variableB) + str(variableC) + str(variableD)
print(cadenaConcatenada)

# Arreglamos el formato
cadenaConcatenada = str(variableA) +" "+ str(variableB) +" "+ str(variableC) +" "+ str(variableD)
print(cadenaConcatenada)

# Forma especial con "la cadena f"
cadenaConcatenada = f'{variableA} {variableB} {variableC} {variableD}'
print(cadenaConcatenada)
# Out:
# una frase101.75['A', 'B', 'C']
# una frase 10 1.75 ['A', 'B', 'C']
# una frase 10 1.75 ['A', 'B', 'C']
